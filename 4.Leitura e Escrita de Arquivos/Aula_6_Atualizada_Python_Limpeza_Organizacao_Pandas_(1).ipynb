# %% [markdown]
# # 📘 Aula 6 – Limpeza e Organização de Dados com `pandas`
# **Objetivos da Aula**:
# - Identificar e tratar valores ausentes.
# - Renomear colunas e padronizar nomes.
# - Alterar o tipo de dados (casting).
# - Filtrar e ordenar registros.
# - Corrigir registros com erros ou duplicações.

# %% [markdown]
# ## 🧠 Parte 1 – Por que limpar os dados?
# Na prática, os dados podem ter:
# - Erros de digitação
# - Valores ausentes
# - Formatos inconsistentes
# - Colunas mal nomeadas

# %% [markdown]
# ## 🧹 Parte 2 – Lidando com valores ausentes

# %%
import pandas as pd

df = pd.read_csv("vendas_ausente.csv", sep=";", decimal=",")
df.isnull()
df.isnull().sum()
# Out:
# produto            9
# quantidade        19
# preco_unitario     6
# data_venda         0
# valor_total       23
# custo_total       32
# dtype: int64

# %%
df.isnull()
df.isnull().sum()
# Out:
# produto            0
# quantidade         0
# preco_unitario     6
# data_venda         0
# receita_total     23
# custo_total        0
# dtype: int64

# %%
display(df)
# Out:
#         produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0       Monitor         5.0           120.0  2023-04-13        600.0
# 1       Teclado        10.0           900.0  2023-12-15       9000.0
# 2         Mouse        10.0           900.0  2023-09-28       9000.0
# 3      Notebook        15.0           120.0  2023-04-17       1800.0
# 4    Impressora        15.0            80.0  2023-03-13       1200.0
# ..          ...         ...             ...         ...          ...
# 205     Monitor         5.0           120.0  2023-04-13        600.0
# 206     Monitor         5.0           120.0  2023-04-13        600.0
# 207     Monitor         5.0           120.0  2023-04-13        600.0
# 208     Monitor         5.0           120.0  2023-04-13        600.0
# 209     Monitor         5.0           120.0  2023-04-13        600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %%
df_sem_nulos = df.dropna()
display(df_sem_nulos)
# Out:
#         produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0       Monitor         5.0           120.0  2023-04-13        600.0
# 1       Teclado        10.0           900.0  2023-12-15       9000.0
# 2         Mouse        10.0           900.0  2023-09-28       9000.0
# 3      Notebook        15.0           120.0  2023-04-17       1800.0
# 4    Impressora        15.0            80.0  2023-03-13       1200.0
# ..          ...         ...             ...         ...          ...
# 205     Monitor         5.0           120.0  2023-04-13        600.0
# 206     Monitor         5.0           120.0  2023-04-13        600.0
# 207     Monitor         5.0           120.0  2023-04-13        600.0
# 208     Monitor         5.0           120.0  2023-04-13        600.0
# 209     Monitor         5.0           120.0  2023-04-13        600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [172 rows x 6 columns]

# %%
import numpy as np
#df["quantidade"].replace("", np.nan, inplace=True)
df["quantidade"].fillna(0, inplace=True) # aonde tiver valores NA substitui por ZERO

df["produto"].fillna("desconhecido", inplace=True) # aonde tiver NA  preencher com DESCONHECIDO
df["custo_total"].fillna(0, inplace=True)

display(df)
# Out:
# /tmp/ipython-input-3418842379.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["quantidade"].fillna(0, inplace=True) # aonde tiver valores NA substitui por ZERO
# /tmp/ipython-input-3418842379.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["produto"].fillna("desconhecido", inplace=True) # aonde tiver NA  preencher com DESCONHECIDO
# /tmp/ipython-input-3418842379.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["custo_total"].fillna(0, inplace=True)
#         produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0       Monitor         5.0           120.0  2023-04-13        600.0
# 1       Teclado        10.0           900.0  2023-12-15       9000.0
# 2         Mouse        10.0           900.0  2023-09-28       9000.0
# 3      Notebook        15.0           120.0  2023-04-17       1800.0
# 4    Impressora        15.0            80.0  2023-03-13       1200.0
# ..          ...         ...             ...         ...          ...
# 205     Monitor         5.0           120.0  2023-04-13        600.0
# 206     Monitor         5.0           120.0  2023-04-13        600.0
# 207     Monitor         5.0           120.0  2023-04-13        600.0
# 208     Monitor         5.0           120.0  2023-04-13        600.0
# 209     Monitor         5.0           120.0  2023-04-13        600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %% [markdown]
# ## 🏷️ Parte 3 – Renomeando colunas

# %%
df.rename(columns={"valor_total": "receita_total"}, inplace=True) #"nome antigo":"nome novo"
display(df)
# Out:
#         produto  quantidade  preco_unitario  data_venda  receita_total  \
# 0       Monitor         5.0           120.0  2023-04-13          600.0
# 1       Teclado        10.0           900.0  2023-12-15         9000.0
# 2         Mouse        10.0           900.0  2023-09-28         9000.0
# 3      Notebook        15.0           120.0  2023-04-17         1800.0
# 4    Impressora        15.0            80.0  2023-03-13         1200.0
# ..          ...         ...             ...         ...            ...
# 205     Monitor         5.0           120.0  2023-04-13          600.0
# 206     Monitor         5.0           120.0  2023-04-13          600.0
# 207     Monitor         5.0           120.0  2023-04-13          600.0
# 208     Monitor         5.0           120.0  2023-04-13          600.0
# 209     Monitor         5.0           120.0  2023-04-13          600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_").str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
display(df.columns)
# Out:
# Index(['produto', 'quantidade', 'preco_unitario', 'data_venda',
#        'receita_total', 'custo_total'],
#       dtype='object')

# %% [markdown]
# ## 🔄 Parte 4 – Alterar tipos de dados

# %%
df.dtypes
# Out:
# produto            object
# quantidade        float64
# preco_unitario    float64
# data_venda         object
# receita_total     float64
# custo_total       float64
# dtype: object

# %%
df["quantidade"] = pd.to_numeric(df["quantidade"])
df["data_venda"] = pd.to_datetime(df["data_venda"], errors='coerce')
print(df.dtypes)
# Out:
# produto                   object
# quantidade               float64
# preco_unitario           float64
# data_venda        datetime64[ns]
# receita_total            float64
# custo_total              float64
# dtype: object

# %%
display(df)
# Out:
#         produto  quantidade  preco_unitario data_venda  receita_total  \
# 0       Monitor         5.0           120.0 2023-04-13          600.0
# 1       Teclado        10.0           900.0 2023-12-15         9000.0
# 2         Mouse        10.0           900.0 2023-09-28         9000.0
# 3      Notebook        15.0           120.0 2023-04-17         1800.0
# 4    Impressora        15.0            80.0 2023-03-13         1200.0
# ..          ...         ...             ...        ...            ...
# 205     Monitor         5.0           120.0 2023-04-13          600.0
# 206     Monitor         5.0           120.0 2023-04-13          600.0
# 207     Monitor         5.0           120.0 2023-04-13          600.0
# 208     Monitor         5.0           120.0 2023-04-13          600.0
# 209     Monitor         5.0           120.0 2023-04-13          600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %% [markdown]
# ## 🗂️ Parte 5 – Filtrar e ordenar dados

# %%
#filtrando por partes
df_monitor=df[df["produto"]=="Monitor"]
#display(df_monitor)
df_monitor_preco150=df_monitor[df_monitor["preco_unitario"]>=150]
display(df_monitor_preco150)
# Out:
#      produto  quantidade  preco_unitario data_venda  receita_total  \
# 5    Monitor         5.0           900.0 2023-07-08         4500.0
# 11   Monitor         5.0           900.0 2023-03-29         4500.0
# 89   Monitor        20.0           250.0 2023-07-07         5000.0
# 90   Monitor        15.0          3500.0 2023-02-10        52500.0
# 91   Monitor         5.0          3500.0 2023-06-06        17500.0
# 116  Monitor         5.0           900.0 2023-03-03         4500.0
# 132  Monitor        15.0          3500.0 2023-10-10        52500.0
# 142  Monitor        15.0           250.0 2023-02-21         3750.0
# 144  Monitor         5.0           900.0 2023-08-10         4500.0
# 153  Monitor        10.0           900.0 2023-11-23         9000.0
# 178  Monitor        15.0           250.0 2023-08-21         3750.0
# 196  Monitor        15.0          3500.0 2023-11-14        52500.0
# 198  Monitor         0.0          3500.0 2023-09-25            NaN
#
#       custo_total
# 5        0.000000
# 11    3076.768816
# 89       0.000000
# 90   33348.748392
# 91   11271.693066
# 116   3335.446275
# 132  31833.195918
# 142   2999.921330
# 144   3434.339371
# 153   5861.214665
# 178   3064.188727
# 196  33045.482963
# 198      0.000000

# %%
#filtragem direta
df_monitor_preco150=df[(df["produto"]=="Monitor") & (df["preco_unitario"]>=150)]
#display(df_monitor_preco150)
df_monitor_preco150=df[(df["produto"]=="Monitor") & (df["preco_unitario"]>=150)
  & (df["data_venda"]>"2023-07-07")
]
#display(df_monitor_preco150)

df_monitor_preco150=df[(df["produto"]=="Monitor") & (df["preco_unitario"]>=150)
  & (df["data_venda"].dt.strftime("%m-%d")<="07-07")
]
#display(df_monitor_preco150)

df_monitor_preco150=df[(df["produto"]=="Monitor") & (df["preco_unitario"]>=150)
  & (df["data_venda"].dt.strftime("%y")>="2023")
] # a partir de 01 de janeiro de 2023
display(df_monitor_preco150)



#di.index.strftime("%m-%d") == "08-16"
# Out:
#      produto  quantidade  preco_unitario data_venda  receita_total  \
# 5    Monitor         5.0           900.0 2023-07-08         4500.0
# 11   Monitor         5.0           900.0 2023-03-29         4500.0
# 89   Monitor        20.0           250.0 2023-07-07         5000.0
# 90   Monitor        15.0          3500.0 2023-02-10        52500.0
# 91   Monitor         5.0          3500.0 2023-06-06        17500.0
# 116  Monitor         5.0           900.0 2023-03-03         4500.0
# 132  Monitor        15.0          3500.0 2023-10-10        52500.0
# 142  Monitor        15.0           250.0 2023-02-21         3750.0
# 144  Monitor         5.0           900.0 2023-08-10         4500.0
# 153  Monitor        10.0           900.0 2023-11-23         9000.0
# 178  Monitor        15.0           250.0 2023-08-21         3750.0
# 196  Monitor        15.0          3500.0 2023-11-14        52500.0
# 198  Monitor         0.0          3500.0 2023-09-25            NaN
#
#       custo_total
# 5        0.000000
# 11    3076.768816
# 89       0.000000
# 90   33348.748392
# 91   11271.693066
# 116   3335.446275
# 132  31833.195918
# 142   2999.921330
# 144   3434.339371
# 153   5861.214665
# 178   3064.188727
# 196  33045.482963
# 198      0.000000

# %%
df[(df["produto"] == "Notebook") & (df["quantidade"] > 5)]
# Out:
#       produto  quantidade  preco_unitario data_venda  receita_total  \
# 3    Notebook        15.0           120.0 2023-04-17         1800.0
# 6    Notebook        10.0          3500.0 2023-01-21        35000.0
# 10   Notebook        15.0           900.0 2023-11-27        13500.0
# 22   Notebook        20.0           120.0 2023-10-04         2400.0
# 37   Notebook        10.0           120.0 2023-12-30         1200.0
# 39   Notebook        15.0             NaN 2023-09-01            NaN
# 59   Notebook        20.0           120.0 2023-07-25         2400.0
# 63   Notebook        20.0          3500.0 2023-01-02        70000.0
# 64   Notebook        10.0           120.0 2023-02-23         1200.0
# 66   Notebook        20.0          3500.0 2023-09-17        70000.0
# 95   Notebook        20.0           120.0 2023-12-11         2400.0
# 102  Notebook        20.0            80.0 2023-05-19         1600.0
# 120  Notebook        20.0           900.0 2023-06-21        18000.0
# 141  Notebook        15.0           900.0 2023-08-29        13500.0
# 143  Notebook        20.0           900.0 2023-04-06        18000.0
# 148  Notebook        15.0           120.0 2023-06-20         1800.0
# 149  Notebook        15.0          3500.0 2023-01-29        52500.0
# 152  Notebook        15.0            80.0 2023-06-09         1200.0
# 158  Notebook        15.0          3500.0 2023-03-07        52500.0
# 169  Notebook        10.0           900.0 2023-11-27         9000.0
# 170  Notebook        20.0          3500.0 2023-05-08        70000.0
# 191  Notebook        15.0          3500.0 2023-06-09        52500.0
# 192  Notebook        20.0           120.0 2023-04-06         2400.0
# 193  Notebook        20.0           250.0 2023-08-21         5000.0
#
#       custo_total
# 3     1484.808558
# 6    28931.630971
# 10   10218.514679
# 22    1460.119461
# 37       0.000000
# 39       0.000000
# 59    1531.523426
# 63   54887.774123
# 64    1000.310104
# 66   49889.689000
# 95       0.000000
# 102   1019.465091
# 120  13159.756212
# 141   8451.366464
# 143  11603.450979
# 148   1405.020119
# 149  42731.016144
# 152    920.425541
# 158  34228.507099
# 169   6003.143192
# 170  52922.605887
# 191  38399.683643
# 192   1543.007572
# 193   3340.384158

# %%
# corrigir os problemas com receita_total

df["receita_total"].fillna(df["quantidade"] * df["preco_unitario"], inplace=True)

#df["receita_total"] = df["quantidade"] * df["preco_unitario"]

#df.dropna()

#df.isnull()
#df.isnull().sum()



display(df)
# Out:
# /tmp/ipython-input-3311814856.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["receita_total"].fillna(df["quantidade"] * df["preco_unitario"], inplace=True)
#         produto  quantidade  preco_unitario data_venda  receita_total  \
# 0       Monitor         5.0           120.0 2023-04-13          600.0
# 1       Teclado        10.0           900.0 2023-12-15         9000.0
# 2         Mouse        10.0           900.0 2023-09-28         9000.0
# 3      Notebook        15.0           120.0 2023-04-17         1800.0
# 4    Impressora        15.0            80.0 2023-03-13         1200.0
# ..          ...         ...             ...        ...            ...
# 205     Monitor         5.0           120.0 2023-04-13          600.0
# 206     Monitor         5.0           120.0 2023-04-13          600.0
# 207     Monitor         5.0           120.0 2023-04-13          600.0
# 208     Monitor         5.0           120.0 2023-04-13          600.0
# 209     Monitor         5.0           120.0 2023-04-13          600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %%
import numpy as np
import pandas as pd

# Se houver espaços no nome da coluna:
df.columns = df.columns.str.strip()

# Converta vazios e rótulos comuns de "na" para NaN
df = df.replace(r"^\s*$", np.nan, regex=True).replace(
    ["NaN", "nan", "NA", "None"], np.nan
)

# (Opcional) Troque infinitos por NaN
df = df.replace([np.inf, -np.inf], np.nan)

# %%
df.dropna()

df.isnull()
df.isnull().sum()
# Out:
# produto           0
# quantidade        0
# preco_unitario    6
# data_venda        0
# receita_total     6
# custo_total       0
# dtype: int64

# %%
df.sort_values(by="valor_total", ascending=False) #ordem crescente = falso

# %% [markdown]
# ## ♻️ Parte 6 – Remover duplicações

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## 📝 Parte 7 – Exercícios
# ### 🔹 Exercício 1
# Carregue o arquivo `empregados2.csv` e:
# - Corrija os nomes das colunas
# - Preencha salários ausentes com 0
# - Ordene do maior para o menor salário
#
# ### 🔹 Exercício 2
# Com o arquivo `estoque2.csv`:
# - Adicione coluna `valor_total` = quantidade × preço
# - Remova produtos com quantidade igual a 0
# - Calcule o valor total do estoque
#
# ### 🔹 Exercício 3
# Com o arquivo `financeiro.csv`:
# - Renomeie `mês` para `mes`
# - Crie coluna `resultado` (receita - despesa)
# - Calcule o saldo acumulado

# %%
import pandas as pd

df = pd.read_csv("/content/empregados2.csv", sep=";", decimal=",", encoding='latin-1')
df.isnull()
df.isnull().sum()
# Out:
# funcionário       0
# salario mês      23
# cargo ocupado     0
# dtype: int64

# %%
# renomear colunas (exercicio 1)
df.columns = df.columns.str.lower().str.replace(" ", "_").str.normalize("NFKD").str.encode("ascii", errors="ignore").str.decode("utf-8")
display(df.columns)
# Out:
# Index(['funcionario', 'salario_mes', 'cargo_ocupado'], dtype='object')

# %%
#Preencha salários ausentes com 0

df["salario_mes"].fillna(0, inplace=True)
#display(df)

df.isnull()
df.isnull().sum()
# Out:
# /tmp/ipython-input-733050708.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["salario_mes"].fillna(0, inplace=True)
# funcionario      0
# salario_mes      0
# cargo_ocupado    0
# dtype: int64

# %%
# Ordene do maior para o menor salário (decrescente)

df.sort_values(by="salario_mes", ascending=False) #ordem crescente = falso
# Out:
#          funcionario  salario_mes cargo_ocupado
# 1      Funcionario 2       7500.0   Coordenador
# 13    Funcionario 14       7500.0       Diretor
# 37    Funcionario 38       7500.0    Assistente
# 39    Funcionario 40       7500.0    Assistente
# 41    Funcionario 42       7500.0       Diretor
# ..               ...          ...           ...
# 158  Funcionario 159          0.0       Diretor
# 189  Funcionario 190          0.0       Gerente
# 199  Funcionario 200          0.0   Coordenador
# 195  Funcionario 196          0.0    Assistente
# 194  Funcionario 195          0.0       Gerente
#
# [210 rows x 3 columns]

# %% [markdown]
# ## 🔁 Parte 8 – Revisão da Aula
# | Tarefa                     | Comando                                |
# |----------------------------|-----------------------------------------|
# | Ver valores ausentes       | `df.isnull().sum()`                     |
# | Remover ausentes           | `df.dropna()`                           |
# | Preencher ausentes         | `df["coluna"].fillna(valor)`            |
# | Renomear colunas           | `df.rename(columns={...})`             |
# | Padronizar nomes           | `df.columns = df.columns.str.lower()`  |
# | Converter tipo de dado     | `pd.to_numeric()` ou `pd.to_datetime()`|
# | Filtrar linhas             | `df[condição]`                          |
# | Ordenar                    | `df.sort_values(by="coluna")`         |
# | Remover duplicatas         | `df.drop_duplicates()`                 |

# %% [markdown]
# ## 🧩 Tarefa para Casa
# Utilize o arquivo `financeiro.csv`:
# 1. Corrija o nome da coluna `mês` para `mes`.
# 2. Preencha valores ausentes com 0.
# 3. Crie a coluna `resultado` = receita - despesa.
# 4. Crie a coluna `situacao`, onde:
#    - “lucro” se `resultado > 0`
#    - “prejuízo” se `resultado < 0`
#    - “equilíbrio” se `resultado == 0`
# 5. Exiba o total de meses com lucro, prejuízo e equilíbrio.

# %% [markdown]
# ### Resolução Exercício 2
# Com o arquivo `estoque2.csv`:
# - Adicione coluna `valor_total` = quantidade × preço
# - Remova produtos com quantidade igual a 0
# - Calcule o valor total do estoque

# %%
import pandas as pd

df = pd.read_csv("/content/estoque2.csv", sep=";", decimal=",")
df.isnull()
df.isnull().sum()
# Out:
# produto       0
# quantidade    0
# preco         0
# dtype: int64

# %%
df.head()
# Out:
#       produto  quantidade  preco
# 0       Lápis          20  98.22
# 1       Lápis          50  92.88
# 2    Borracha          10  34.23
# 3  Grampeador         100  70.75
# 4       Lápis           0  65.26

# %%
df["Valor Total"]=df["quantidade"]*df["preco"]
display(df)
# Out:
#         produto  quantidade  preco  Valor Total
# 0         Lápis          20  98.22       1964.4
# 1         Lápis          50  92.88       4644.0
# 2      Borracha          10  34.23        342.3
# 3    Grampeador         100  70.75       7075.0
# 4         Lápis           0  65.26          0.0
# ..          ...         ...    ...          ...
# 205       Lápis          50  92.88       4644.0
# 206       Lápis          50  92.88       4644.0
# 207       Lápis          50  92.88       4644.0
# 208       Lápis          50  92.88       4644.0
# 209       Lápis          50  92.88       4644.0
#
# [210 rows x 4 columns]

# %%
novadf=df[df["quantidade"]!=0] # != diferente

# %%
display(novadf)
# Out:
#         produto  quantidade  preco  Valor Total
# 0         Lápis          20  98.22       1964.4
# 1         Lápis          50  92.88       4644.0
# 2      Borracha          10  34.23        342.3
# 3    Grampeador         100  70.75       7075.0
# 5    Grampeador          10  21.67        216.7
# ..          ...         ...    ...          ...
# 205       Lápis          50  92.88       4644.0
# 206       Lápis          50  92.88       4644.0
# 207       Lápis          50  92.88       4644.0
# 208       Lápis          50  92.88       4644.0
# 209       Lápis          50  92.88       4644.0
#
# [191 rows x 4 columns]

# %%
print("Estoque total {:.2f}" .format(novadf["Valor Total"].sum()))   #soma todas as células da coluna
# Out:
# Estoque total 372900.40

# %% [markdown]
# ## 🧠 Complemento – Aprofundamento prático com `pandas`

# %% [markdown]
# ### 🔍 Acessando e manipulando dados com `.loc` e `.iloc`

# %%
import pandas as pd

df = pd.read_csv("vendas_ausente.csv", sep=";", decimal=",")
df.isnull()
df.isnull().sum()
# Out:
# produto            9
# quantidade        19
# preco_unitario     6
# data_venda         0
# valor_total       23
# custo_total       32
# dtype: int64

# %%
# Selecionar a primeira linha inteira
print(df.loc[0])
# Out:
# produto              Monitor
# quantidade               5.0
# preco_unitario         120.0
# data_venda        2023-04-13
# valor_total            600.0
# custo_total       472.141407
# Name: 0, dtype: object

# %%
display(df)
# Out:
#         produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0       Monitor         5.0           120.0  2023-04-13        600.0
# 1       Teclado        10.0           900.0  2023-12-15       9000.0
# 2         Mouse        10.0           900.0  2023-09-28       9000.0
# 3      Notebook        15.0           120.0  2023-04-17       1800.0
# 4    Impressora        15.0            80.0  2023-03-13       1200.0
# ..          ...         ...             ...         ...          ...
# 205     Monitor         5.0           120.0  2023-04-13        600.0
# 206     Monitor         5.0           120.0  2023-04-13        600.0
# 207     Monitor         5.0           120.0  2023-04-13        600.0
# 208     Monitor         5.0           120.0  2023-04-13        600.0
# 209     Monitor         5.0           120.0  2023-04-13        600.0
#
#      custo_total
# 0     472.141407
# 1    6531.120878
# 2    5922.478564
# 3    1484.808558
# 4     835.167366
# ..           ...
# 205   472.141407
# 206   472.141407
# 207   472.141407
# 208   472.141407
# 209   472.141407
#
# [210 rows x 6 columns]

# %%
# Selecionar todas as vendas de Notebook
print(df.loc[df["produto"] == "Notebook"])
# Out:
#       produto  quantidade  preco_unitario  data_venda  valor_total  \
# 3    Notebook        15.0           120.0  2023-04-17       1800.0
# 6    Notebook        10.0          3500.0  2023-01-21      35000.0
# 10   Notebook        15.0           900.0  2023-11-27      13500.0
# 22   Notebook        20.0           120.0  2023-10-04       2400.0
# 26   Notebook         5.0           250.0  2023-09-10       1250.0
# 29   Notebook         5.0           750.0  2023-02-18       3750.0
# 37   Notebook        10.0           120.0  2023-12-30       1200.0
# 39   Notebook        15.0             NaN  2023-09-01          NaN
# 48   Notebook         NaN            80.0  2023-03-30          NaN
# 59   Notebook        20.0           120.0  2023-07-25       2400.0
# 63   Notebook        20.0          3500.0  2023-01-02      70000.0
# 64   Notebook        10.0           120.0  2023-02-23       1200.0
# 66   Notebook        20.0          3500.0  2023-09-17      70000.0
# 80   Notebook         5.0           120.0  2023-10-23        600.0
# 95   Notebook        20.0           120.0  2023-12-11       2400.0
# 102  Notebook        20.0            80.0  2023-05-19       1600.0
# 117  Notebook         5.0           900.0  2023-08-04       4500.0
# 120  Notebook        20.0           900.0  2023-06-21      18000.0
# 141  Notebook        15.0           900.0  2023-08-29      13500.0
# 143  Notebook        20.0           900.0  2023-04-06      18000.0
# 148  Notebook        15.0           120.0  2023-06-20       1800.0
# 149  Notebook        15.0          3500.0  2023-01-29      52500.0
# 152  Notebook        15.0            80.0  2023-06-09       1200.0
# 157  Notebook         NaN          3500.0  2023-10-11          NaN
# 158  Notebook        15.0          3500.0  2023-03-07      52500.0
# 169  Notebook        10.0           900.0  2023-11-27       9000.0
# 170  Notebook        20.0          3500.0  2023-05-08      70000.0
# 190  Notebook         NaN           900.0  2023-11-11          NaN
# 191  Notebook        15.0          3500.0  2023-06-09      52500.0
# 192  Notebook        20.0           120.0  2023-04-06       2400.0
# 193  Notebook        20.0           250.0  2023-08-21       5000.0
# 197  Notebook         5.0           120.0  2023-02-21        600.0
#
#       custo_total
# 3     1484.808558
# 6    28931.630971
# 10   10218.514679
# 22    1460.119461
# 26     856.900546
# 29    3043.549024
# 37            NaN
# 39            NaN
# 48            NaN
# 59    1531.523426
# 63   54887.774123
# 64    1000.310104
# 66   49889.689000
# 80     410.024876
# 95            NaN
# 102   1019.465091
# 117   2773.922219
# 120  13159.756212
# 141   8451.366464
# 143  11603.450979
# 148   1405.020119
# 149  42731.016144
# 152    920.425541
# 157           NaN
# 158  34228.507099
# 169   6003.143192
# 170  52922.605887
# 190           NaN
# 191  38399.683643
# 192   1543.007572
# 193   3340.384158
# 197    446.477471

# %%
# Alterar o produto da primeira linha para 'Notebook'
df.loc[0, "produto"] = "Notebook"
# Alterar o preço unitario da quinta linha para 100
df.loc[4, "preco_unitario"] = 100
df.head()
# Out:
#       produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0    Notebook         5.0           120.0  2023-04-13        600.0
# 1     Teclado        10.0           900.0  2023-12-15       9000.0
# 2       Mouse        10.0           900.0  2023-09-28       9000.0
# 3    Notebook        15.0           120.0  2023-04-17       1800.0
# 4  Impressora        15.0           100.0  2023-03-13       1200.0
#
#    custo_total
# 0   472.141407
# 1  6531.120878
# 2  5922.478564
# 3  1484.808558
# 4   835.167366

# %%
# Selecionar a primeira linha (por posição)
print(df.iloc[0])
# Out:
# produto             Notebook
# quantidade               5.0
# preco_unitario         120.0
# data_venda        2023-04-13
# valor_total            600.0
# custo_total       472.141407
# Name: 0, dtype: object

# %%
# Selecionar valor da linha 0 e coluna 3 (coluna começa com ZERO)
print(df.iloc[0, 2])
# Out:
# 120.0

# %%
# Selecionar as 7 primeiras linhas e 3 primeiras colunas
print(df.iloc[:7, :3])
# Out:
#       produto  quantidade  preco_unitario
# 0    Notebook         5.0           120.0
# 1     Teclado        10.0           900.0
# 2       Mouse        10.0           900.0
# 3    Notebook        15.0           120.0
# 4  Impressora        15.0           100.0
# 5     Monitor         5.0           900.0
# 6    Notebook        10.0          3500.0

# %% [markdown]
# ### 🛠️ Usando `.apply()` para aplicar funções em colunas

# %%
# Criar nova coluna com classificação do valor_total

def classificar(valor):
    if valor >= 20000:
        return "alta"
    elif valor >= 10000:
        return "média"
    else:
        return "baixa"

# %%
# Antes de aplicar, preencher valores ausentes com 0 para evitar erro
valor_total_sem_nan = df["valor_total"].fillna(0)
valor_total_sem_nan.head()
# Out:
# 0     600.0
# 1    9000.0
# 2    9000.0
# 3    1800.0
# 4    1200.0
# Name: valor_total, dtype: float64

# %%
df["categoria"] = valor_total_sem_nan.apply(classificar)
df[["valor_total", "categoria"]].head()
# Out:
#    valor_total categoria
# 0        600.0     baixa
# 1       9000.0     baixa
# 2       9000.0     baixa
# 3       1800.0     baixa
# 4       1200.0     baixa

# %% [markdown]
# ### 📊 Usando `.value_counts()` para contagens

# %%
display(df)
# Out:
#         produto  quantidade  preco_unitario  data_venda  valor_total  \
# 0      Notebook         5.0           120.0  2023-04-13        600.0
# 1       Teclado        10.0           900.0  2023-12-15       9000.0
# 2         Mouse        10.0           900.0  2023-09-28       9000.0
# 3      Notebook        15.0           120.0  2023-04-17       1800.0
# 4    Impressora        15.0           100.0  2023-03-13       1200.0
# ..          ...         ...             ...         ...          ...
# 205     Monitor         5.0           120.0  2023-04-13        600.0
# 206     Monitor         5.0           120.0  2023-04-13        600.0
# 207     Monitor         5.0           120.0  2023-04-13        600.0
# 208     Monitor         5.0           120.0  2023-04-13        600.0
# 209     Monitor         5.0           120.0  2023-04-13        600.0
#
#      custo_total categoria
# 0     472.141407     baixa
# 1    6531.120878     baixa
# 2    5922.478564     baixa
# 3    1484.808558     baixa
# 4     835.167366     baixa
# ..           ...       ...
# 205   472.141407     baixa
# 206   472.141407     baixa
# 207   472.141407     baixa
# 208   472.141407     baixa
# 209   472.141407     baixa
#
# [210 rows x 7 columns]

# %%
# Número de aparições de cada produto
print(df["produto"].value_counts())
# Out:
# produto
# Monitor       40
# Impressora    39
# Notebook      33
# Mouse         30
# Teclado       23
# Webcam        21
# Headset       15
# Name: count, dtype: int64

# %%
# Vezes em que apareceu numero igual na coluna quantidade
print(df["quantidade"].value_counts())
# Out:
# quantidade
# 5.0     54
# 20.0    53
# 15.0    47
# 10.0    37
# Name: count, dtype: int64

# %%
# Se tiver a coluna 'situacao', mostrar total de cada tipo
if "situacao" in df.columns:
    print(df["situacao"].value_counts())

# %%
if "valor_total" in df.columns:
    print(df["valor_total"].value_counts())
# Out:
# valor_total
# 600.0      23
# 1200.0     19
# 1600.0     14
# 2400.0     12
# 800.0      11
# 52500.0    11
# 1800.0     10
# 70000.0     9
# 4500.0      8
# 400.0       8
# 3750.0      7
# 9000.0      7
# 18000.0     7
# 17500.0     6
# 15000.0     6
# 7500.0      5
# 11250.0     5
# 1250.0      5
# 5000.0      4
# 13500.0     4
# 35000.0     3
# 2500.0      3
# Name: count, dtype: int64
