# %% [markdown]
# Nome: Sérgio Ricardo Vieira Torres Silva
#
# Curso: Economia
#
# Matrícula: 21211879

# %% [markdown]
# ## 📝 Exercícios 1
#
# Carregue um CSV de despesas mensais Mostre:
# - a) As 5 primeiras linhas
# - b) Total de despesas (coluna `valor`)
# - c) Média das despesas

# %%
#a) carregando 5 prieiras linhas
import pandas as pd
dados = pd.read_csv("/content/financeiro.csv", encoding="latin1", sep=";")
dados.head()
# Out:
#          mês  receita  despesa
# 0    Janeiro    20000    15000
# 1  Fevereiro    22000    17000
# 2      Marco    21000    16000
# 3      Abril    23000    18000
# 4       Maio    25000    19000

# %%
#b) Total de despesas(somatório de todos os valores da coluna "despesa")
Total_despesa = dados['despesa'].sum()
print(f"O total de despesas é de: {Total_despesa:.2f}")
# Out:
# O total de despesas é de: 85000.00

# %%
#c) Média das despesas
media_despesa = dados["despesa"].mean()
print(f"A média das despesas é de {media_despesa:.2f}")
# Out:
# A média das despesas é de 17000.00

# %% [markdown]
# ### 📝 Exercício 2
# Com uma planilha de salários (`funcionario`, `salario`, `cargo`):
# - a) Salário médio
# - b) Quantos ganham mais de R$ 5000?
# - c) Crie nova coluna `salario_anual`

# %%
#lendo o arquivo empregados que contém o salário de cada pessoa
dados = pd.read_csv("/content/empregados.csv", sep=";")
# Out:
#       funcionario  salario        cargo
# 0       Ana Silva   4500.0     Analista
# 1    Carlos Souza   5200.0  Coordenador
# 2    Beatriz Lima   6100.0      Gerente
# 3     João Mendes   4800.0   Assistente
# 4  Fernanda Rocha   7000.0      Diretor

# %%
#a) Salário médio
media_salario = dados["salario"].mean()
print(f"O salário médio é de {media_salario:.2f}")
# Out:
# O salário médio é de 5520.00

# %%
#b) verificando quantos ganham acima de 5000
acima_5000 = dados[dados['salario'] > 5000]
print(f"O número de funcionários que ganham mais de R$ 5000 é de: {len(acima_5000)}")
# Out:
# O número de funcionários que ganham mais de R$ 5000 é de: 3

# %%
# c) Criando uma nova coluna "salario anual"
dados['salario_anual'] = dados['salario'] * 12
dados.head()
# Out:
#       funcionario  salario        cargo  salario_anual
# 0       Ana Silva   4500.0     Analista        54000.0
# 1    Carlos Souza   5200.0  Coordenador        62400.0
# 2    Beatriz Lima   6100.0      Gerente        73200.0
# 3    JoÃ£o Mendes   4800.0   Assistente        57600.0
# 4  Fernanda Rocha   7000.0      Diretor        84000.0

# %% [markdown]
# ## 📝 Exercício 3
# Com `estoque.csv` (`produto`, `quantidade`, `preco`):
# - Calcule o valor total de cada produto (quantidade × preço)
# - Calcule o valor total do estoque

# %%
#a) Calculando o valor total de cada produto(quantidade x preço)
dados = pd.read_csv("/content/estoque.csv", sep=";")
dados['valor_total'] = dados['quantidade'] * dados['preco']
dados.head()
# Out:
#      produto  quantidade  preco  valor_total
# 0     Caneta         100    2.5        250.0
# 1    Caderno          50   12.0        600.0
# 2    Mochila          20   90.0       1800.0
# 3      Lápis         200    1.2        240.0
# 4  Apontador          80    3.8        304.0

# %%
# b) Calculando o valor total do estoque
valor_total_estoque = dados['valor_total'].sum()
print(f"O valor total do estoque é de: {valor_total_estoque:.2f}")
# Out:
# O valor total do estoque é de: 3194.00

# %% [markdown]
# ## 🧩 Tarefa para Casa
# Crie um arquivo `financeiro.csv` com as colunas:
# - `mês`, `receita`, `despesa`
#
# Escreva um programa que:
# 1. Carregue o arquivo
# 2. Crie a coluna `resultado` (receita - despesa)
# 3. Mostre o resultado mês a mês
# 4. Mostre o **saldo acumulado** (soma dos resultados)

# %%
#1) Carregando o arquivo
import pandas as pd

#2) criando a coluna resultado (receita-despesa)
dados = pd.read_csv("/content/financeiro2.csv", encoding="utf8", sep=",")
dados['resultado'] = dados['Receita'] - dados['Despesa']
dados.head(

)
# Out:
#          Mês  Receita  Despesa  resultado
# 0    Janeiro     5000     3000       2000
# 1  Fevereiro     5200     3100       2100
# 2      Março     5100     3200       1900
# 3      Abril     5300     3300       2000
# 4       Maio     5500     3400       2100

# %%
# 3) Mostrando o resultado mês a mês
print("Resultado Mês a Mês:")
display(dados[['Mês', 'resultado']])
# Out:
# Resultado Mês a Mês:
#           Mês  resultado
# 0     Janeiro       2000
# 1   Fevereiro       2100
# 2       Março       1900
# 3       Abril       2000
# 4        Maio       2100
# 5       Junho       1900
# 6       Julho       2000
# 7      Agosto       2100
# 8    Setembro       2100
# 9     Outubro       2100
# 10   Novembro       2200
# 11   Dezembro       2200

# %%
#4) Mostre o saldo acumulado (soma dos resultados)
dados['saldo_acumulado'] = dados['resultado'].cumsum()
print("\nSaldo Acumulado:")
display(dados[['Mês', 'saldo_acumulado']])
# Out:
# Saldo Acumulado:
#           Mês  saldo_acumulado
# 0     Janeiro             2000
# 1   Fevereiro             4100
# 2       Março             6000
# 3       Abril             8000
# 4        Maio            10100
# 5       Junho            12000
# 6       Julho            14000
# 7      Agosto            16100
# 8    Setembro            18200
# 9     Outubro            20300
# 10   Novembro            22500
# 11   Dezembro            24700

# %%
#5) craiando as colunas resultado e saldo acumulado
dados['resultado'] = dados['Receita'] - dados['Despesa']
dados['saldo_acumulado'] = dados['resultado'].cumsum()
dados.head(12)
# Out:
#           Mês  Receita  Despesa  resultado  saldo_acumulado
# 0     Janeiro     5000     3000       2000             2000
# 1   Fevereiro     5200     3100       2100             4100
# 2       Março     5100     3200       1900             6000
# 3       Abril     5300     3300       2000             8000
# 4        Maio     5500     3400       2100            10100
# 5       Junho     5400     3500       1900            12000
# 6       Julho     5600     3600       2000            14000
# 7      Agosto     5800     3700       2100            16100
# 8    Setembro     5900     3800       2100            18200
# 9     Outubro     6000     3900       2100            20300
# 10   Novembro     6200     4000       2200            22500
# 11   Dezembro     6300     4100       2200            24700
